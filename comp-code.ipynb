# %% [markdown]
# # Comparison Code

# %% [markdown]
# This code is used to compare found data values with those in literature.
#
# Literature texts used:
# Wevers et. al 2017
# Graur et. al 2018
# Van Velzen et. al 2018

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Setting up index

# %%
M_BH = []
M_GAL =[]

BHerr_max = []
BHerr_min = []

GALerr_max = []
GALerr_min = []

M_BH_wvrs = []
M_BHerr_max_wvrs = []
M_BHerr_min_wvrs = []

M_GAL_grr = []
M_GALerr_max_grr = []
M_GALerr_min_grr = []

M_GAL_van18 = []

# %%
with open("Combining_our_masses_incomplete_no_headers_p.txt") as file:
    for line in file:
        data = line.split(',')
        M_BH.append(float(data[4]))
        M_GAL.append(float(data[1]))
        BHerr_max.append(float(data[5]))
        BHerr_min.append(float(data[6]))
        GALerr_max.append(float(data[2]))
        GALerr_min.append(-float(data[3]))
        M_BH_wvrs.append(float(data[7]))
        M_BHerr_max_wvrs.append(float(data[8]))
        M_BHerr_min_wvrs.append(float(data[9]))
        M_GAL_grr.append(float(data[13]))
        M_GALerr_max_grr.append(float(data[14]))
        M_GALerr_min_grr.append(float(data[15]))
        M_GAL_van18.append(float(data[16]))
        #M_GAL_van20.append(float(data[17]))
        #M_GALerr_max_van20.append(float(data[18]))
        #M_GALerr_min_van20.append(float(data[18]))

# %% [markdown]
# #### Plotting initial scatter graph

# %%
yerror = [GALerr_min, GALerr_max]
xerror = [BHerr_min, BHerr_max]

plt.ylabel('Galaxy Mass')
plt.title('A plot of galaxy mass vs black hole mass for our sample')
plt.xlabel('Black Hole Mass')
plt.errorbar(M_BH, M_GAL, yerr = yerror, xerr = xerror, fmt='o')
plt.show()

# %% [markdown]
# ##### Black Hole Literature Comparison - Wevers 2017

# %%
BH_comp = []
BH_comp.append(M_BH[0])
BH_comp.append(M_BH[1])
BH_comp.append(M_BH[14])
BH_comp.append(M_BH[15])
BH_comp.append(M_BH[17])
BH_comp.append(M_BH[18])
BH_comp.append(M_BH[19])
BH_comp.append(M_BH[24])
BH_comp.append(M_BH[28])
BH_comp.append(M_BH[30])


BHerr_min_comp = []
BHerr_min_comp.append(BHerr_min[0])
BHerr_min_comp.append(BHerr_min[1])
BHerr_min_comp.append(BHerr_min[14])
BHerr_min_comp.append(BHerr_min[15])
BHerr_min_comp.append(BHerr_min[17])
BHerr_min_comp.append(BHerr_min[18])
BHerr_min_comp.append(BHerr_min[19])
BHerr_min_comp.append(BHerr_min[24])
BHerr_min_comp.append(BHerr_min[28])
BHerr_min_comp.append(BHerr_min[30])

BHerr_max_comp = []
BHerr_max_comp.append(BHerr_min[0])
BHerr_max_comp.append(BHerr_min[1])
BHerr_max_comp.append(BHerr_min[14])
BHerr_max_comp.append(BHerr_min[15])
BHerr_max_comp.append(BHerr_min[17])
BHerr_max_comp.append(BHerr_min[18])
BHerr_max_comp.append(BHerr_min[19])
BHerr_max_comp.append(BHerr_min[24])
BHerr_max_comp.append(BHerr_min[28])
BHerr_max_comp.append(BHerr_min[30])

Wvrs_vals = []
Wvrs_vals.append(M_BH_wvrs[0])
Wvrs_vals.append(M_BH_wvrs[1])
Wvrs_vals.append(M_BH_wvrs[14])
Wvrs_vals.append(M_BH_wvrs[15])
Wvrs_vals.append(M_BH_wvrs[17])
Wvrs_vals.append(M_BH_wvrs[18])
Wvrs_vals.append(M_BH_wvrs[19])
Wvrs_vals.append(M_BH_wvrs[24])
Wvrs_vals.append(M_BH_wvrs[28])
Wvrs_vals.append(M_BH_wvrs[30])

Wvrserr_max = []
Wvrserr_max.append(M_BHerr_max_wvrs[0])
Wvrserr_max.append(M_BHerr_max_wvrs[1])
Wvrserr_max.append(M_BHerr_max_wvrs[14])
Wvrserr_max.append(M_BHerr_max_wvrs[15])
Wvrserr_max.append(M_BHerr_max_wvrs[17])
Wvrserr_max.append(M_BHerr_max_wvrs[18])
Wvrserr_max.append(M_BHerr_max_wvrs[19])
Wvrserr_max.append(M_BHerr_max_wvrs[24])
Wvrserr_max.append(M_BHerr_max_wvrs[28])
Wvrserr_max.append(M_BHerr_max_wvrs[30])

Wvrserr_min = []
Wvrserr_min.append(M_BHerr_min_wvrs[0])
Wvrserr_min.append(M_BHerr_min_wvrs[1])
Wvrserr_min.append(M_BHerr_min_wvrs[14])
Wvrserr_min.append(M_BHerr_min_wvrs[15])
Wvrserr_min.append(M_BHerr_min_wvrs[17])
Wvrserr_min.append(M_BHerr_min_wvrs[18])
Wvrserr_min.append(M_BHerr_min_wvrs[19])
Wvrserr_min.append(M_BHerr_min_wvrs[24])
Wvrserr_min.append(M_BHerr_min_wvrs[28])
Wvrserr_min.append(M_BHerr_min_wvrs[30])

yerror_2 = [BHerr_min_comp, BHerr_max_comp]

Wvrs_xtick = ['A14ae', 'A14li', 'i15af', 'PS10jh', 'PT09djl', 'PT09ge', 'TDE1', 'i16fnl', 'i16axa', 'D3-13']

yerror_wvrs = [Wvrserr_min, Wvrserr_max]

x=np.arange(1, 11, 1)
plt.figure()
plt.title('A Comparison of our Black Hole Masses to Wevers et al. 2017')
plt.xticks(ticks=x, labels=Wvrs_xtick, rotation='vertical')
plt.plot(x, BH_comp, 'b.', label='Calculated values', markersize=12)
plt.errorbar(x, BH_comp, yerr = yerror_2, fmt='o')
plt.plot(x, Wvrs_vals, '.', color='orange', label='Wevers 2017', markersize=12) 
plt.errorbar(x, Wvrs_vals, yerr = yerror_wvrs, fmt='o')
plt.legend()
plt.show()

# %% [markdown]
# #### Galaxy Mass Literature Comparison - Graur 2018

# %%
GM_comp = []
GM_comp.append(M_GAL[0])
GM_comp.append(M_GAL[1])
GM_comp.append(M_GAL[14])
GM_comp.append(M_GAL[15])
GM_comp.append(M_GAL[17])
GM_comp.append(M_GAL[19])
GM_comp.append(M_GAL[24])
GM_comp.append(M_GAL[28])
GM_comp.append(M_GAL[30])

GMerr_min_comp = []
GMerr_min_comp.append(GALerr_min[0])
GMerr_min_comp.append(GALerr_min[1])
GMerr_min_comp.append(GALerr_min[14])
GMerr_min_comp.append(GALerr_min[15])
GMerr_min_comp.append(GALerr_min[17])
GMerr_min_comp.append(GALerr_min[19])
GMerr_min_comp.append(GALerr_min[24])
GMerr_min_comp.append(GALerr_min[28])
GMerr_min_comp.append(GALerr_min[30])

GMerr_max_comp = []
GMerr_max_comp.append(GALerr_max[0])
GMerr_max_comp.append(GALerr_max[1])
GMerr_max_comp.append(GALerr_max[14])
GMerr_max_comp.append(GALerr_max[15])
GMerr_max_comp.append(GALerr_max[17])
GMerr_max_comp.append(GALerr_max[19])
GMerr_max_comp.append(GALerr_max[24])
GMerr_max_comp.append(GALerr_max[28])
GMerr_max_comp.append(GALerr_max[30])

Grr_vals = []
Grr_vals.append(M_GAL_grr[0])
Grr_vals.append(M_GAL_grr[1])
Grr_vals.append(M_GAL_grr[14])
Grr_vals.append(M_GAL_grr[15])
Grr_vals.append(M_GAL_grr[17])
Grr_vals.append(M_GAL_grr[19])
Grr_vals.append(M_GAL_grr[24])
Grr_vals.append(M_GAL_grr[28])
Grr_vals.append(M_GAL_grr[30])

Grrerr_min = [] 
Grrerr_min.append(M_GALerr_min_grr[0])
Grrerr_min.append(M_GALerr_min_grr[1])
Grrerr_min.append(M_GALerr_min_grr[14])
Grrerr_min.append(M_GALerr_min_grr[15])
Grrerr_min.append(M_GALerr_min_grr[17])
Grrerr_min.append(M_GALerr_min_grr[19])
Grrerr_min.append(M_GALerr_min_grr[24])
Grrerr_min.append(M_GALerr_min_grr[28])
Grrerr_min.append(M_GALerr_min_grr[30])

Grrerr_max = []
Grrerr_max.append(M_GALerr_max_grr[0])
Grrerr_max.append(M_GALerr_max_grr[1])
Grrerr_max.append(M_GALerr_max_grr[14])
Grrerr_max.append(M_GALerr_max_grr[15])
Grrerr_max.append(M_GALerr_max_grr[17])
Grrerr_max.append(M_GALerr_max_grr[19])
Grrerr_max.append(M_GALerr_max_grr[24])
Grrerr_max.append(M_GALerr_max_grr[28])
Grrerr_max.append(M_GALerr_max_grr[30])

yerror = [GMerr_min_comp, GMerr_max_comp]

Grr_xtick = ['A14ae','A14li','i15af','PS10jh','PT09djl','TDE1','i16fnl','i16axa','D3-13']

yerror_grr = [Grrerr_min, Grrerr_max]

x=np.arange(1, 10, 1)
plt.figure()
plt.title('A Comparison of our Galaxy Masses to Graur et al. 2018')
plt.xticks(ticks=x, labels=Grr_xtick, rotation='vertical')
plt.plot(x, GM_comp, 'b.', label='Calculated values', markersize=12)
plt.errorbar(x, GM_comp, yerr = yerror, fmt='o')
plt.plot(x, Grr_vals, '.', color='orange', label='Graur 2018', markersize=12) #<------ NOTE: For some reason having to make an index, doen't like reading out the txt file (different first dimension?)
plt.errorbar(x, Grr_vals, yerr = yerror_grr, fmt='o')
plt.legend()
plt.show()

# %% [markdown]
# #### Galaxy Mass Literature Comparison - Van Velzen 2018

# %%
GM_comp = []

GM_comp.append(M_GAL[0])
GM_comp.append(M_GAL[1])
GM_comp.append(M_GAL[14])
GM_comp.append(M_GAL[15])
GM_comp.append(M_GAL[16])
GM_comp.append(M_GAL[17])
GM_comp.append(M_GAL[18])
GM_comp.append(M_GAL[19])
GM_comp.append(M_GAL[24])
GM_comp.append(M_GAL[25])
GM_comp.append(M_GAL[26])
GM_comp.append(M_GAL[27])
GM_comp.append(M_GAL[28])
GM_comp.append(M_GAL[30])

GMerr_min_comp = []

GMerr_min_comp.append(GALerr_min[0])
GMerr_min_comp.append(GALerr_min[1])
GMerr_min_comp.append(GALerr_min[14])
GMerr_min_comp.append(GALerr_min[15])
GMerr_min_comp.append(GALerr_min[16])
GMerr_min_comp.append(GALerr_min[17])
GMerr_min_comp.append(GALerr_min[18])
GMerr_min_comp.append(GALerr_min[19])
GMerr_min_comp.append(GALerr_min[24])
GMerr_min_comp.append(GALerr_min[25])
GMerr_min_comp.append(GALerr_min[26])
GMerr_min_comp.append(GALerr_min[27])
GMerr_min_comp.append(GALerr_min[28])
GMerr_min_comp.append(GALerr_min[30])

GMerr_max_comp = []

GMerr_max_comp.append(GALerr_max[0])
GMerr_max_comp.append(GALerr_max[1])
GMerr_max_comp.append(GALerr_max[14])
GMerr_max_comp.append(GALerr_max[15])
GMerr_max_comp.append(GALerr_max[16])
GMerr_max_comp.append(GALerr_max[17])
GMerr_max_comp.append(GALerr_max[18])
GMerr_max_comp.append(GALerr_max[19])
GMerr_max_comp.append(GALerr_max[24])
GMerr_max_comp.append(GALerr_max[25])
GMerr_max_comp.append(GALerr_max[26])
GMerr_max_comp.append(GALerr_max[27])
GMerr_max_comp.append(GALerr_max[28])
GMerr_max_comp.append(GALerr_max[30])

Van_vals = []
Van_vals.append(M_GAL_van18[0])
Van_vals.append(M_GAL_van18[1])
Van_vals.append(M_GAL_van18[14])
Van_vals.append(M_GAL_van18[15])
Van_vals.append(M_GAL_van18[16])
Van_vals.append(M_GAL_van18[17])
Van_vals.append(M_GAL_van18[18])
Van_vals.append(M_GAL_van18[19])
Van_vals.append(M_GAL_van18[24])
Van_vals.append(M_GAL_van18[25])
Van_vals.append(M_GAL_van18[26])
Van_vals.append(M_GAL_van18[27])
Van_vals.append(M_GAL_van18[28])
Van_vals.append(M_GAL_van18[30])

yerror = [GMerr_min_comp, GMerr_max_comp]

Van_xtick = ['A14ae','A14li','i15af','PS10jh','PS11af','PT09djl','PT09ge','TDE1','i16fnl','D1-9','TDE2','A15oi','i16axa','D3-13']

x=np.arange(1, 15, 1)
plt.figure()
plt.title('A Comparison of our Galaxy Masses to Van Velzen et al. 2017')
plt.xticks(ticks=x, labels=Van_xtick, rotation='vertical')
plt.plot(x, GM_comp, 'b.', label='Calculated values', markersize=12)
plt.errorbar(x, GM_comp, yerr = yerror, fmt='o')
plt.plot(x, Van_vals, '.', color='orange', label='Van Velzen 2017', markersize=12) 
plt.errorbar(x, Van_vals, yerr = 0, fmt='o')
plt.legend()
plt.show()

# %% [markdown]
# #### Literature Scatter Comparison - Wevers X Graur

# %%
yerror1 = [[M_GALerr_min_grr[0]], [M_GALerr_max_grr[0]]]
xerror1 = [[M_BHerr_min_wvrs[0]], [M_BHerr_max_wvrs[0]]]

yerror2 = [[M_GALerr_min_grr[1]], [M_GALerr_max_grr[1]]]
xerror2 = [[M_BHerr_min_wvrs[1]], [M_BHerr_max_wvrs[1]]]

yerror3 = [[M_GALerr_min_grr[14]], [M_GALerr_max_grr[14]]]
xerror3 = [[M_BHerr_min_wvrs[14]], [M_BHerr_max_wvrs[14]]]

yerror4 = [[M_GALerr_min_grr[15]], [M_GALerr_max_grr[15]]]
xerror4 = [[M_BHerr_min_wvrs[15]], [M_BHerr_max_wvrs[15]]]

yerror5 = [[M_GALerr_min_grr[17]], [M_GALerr_max_grr[17]]]
xerror5 = [[M_BHerr_min_wvrs[17]], [M_BHerr_max_wvrs[17]]]

yerror6 = [[M_GALerr_min_grr[19]], [M_GALerr_max_grr[19]]]
xerror6 = [[M_BHerr_min_wvrs[19]], [M_BHerr_max_wvrs[19]]]
          
yerror7 = [[M_GALerr_min_grr[24]], [M_GALerr_max_grr[24]]]
xerror7 = [[M_BHerr_min_wvrs[24]], [M_BHerr_max_wvrs[24]]]

yerror8 = [[M_GALerr_min_grr[28]], [M_GALerr_max_grr[28]]]
xerror8 = [[M_BHerr_min_wvrs[28]], [M_BHerr_max_wvrs[28]]]

yerror9 = [[M_GALerr_min_grr[30]], [M_GALerr_max_grr[30]]]
xerror9 = [[M_BHerr_min_wvrs[30]], [M_BHerr_max_wvrs[30]]]

plt.ylabel('Galaxy Mass')
plt.title('Literature scatter - Wevers 2017 X Graur 2018')
plt.xlabel('Black Hole Mass')
plt.errorbar(M_BH_wvrs[0], M_GAL_grr[0], yerr = yerror1, xerr = xerror1, fmt='o', label='A14ae')
plt.errorbar(M_BH_wvrs[1], M_GAL_grr[1], yerr = yerror2, xerr = xerror2, fmt='o', label='A14li')
plt.errorbar(M_BH_wvrs[14], M_GAL_grr[14], yerr = yerror3, xerr = xerror3, fmt='o', label='i15af')
plt.errorbar(M_BH_wvrs[15], M_GAL_grr[15], yerr = yerror4, xerr = xerror4, fmt='o', label='PS10jh')
plt.errorbar(M_BH_wvrs[17], M_GAL_grr[17], yerr = yerror5, xerr = xerror5, fmt='o', label='PT09djl')
plt.errorbar(M_BH_wvrs[19], M_GAL_grr[19], yerr = yerror6, xerr = xerror6, fmt='o', label='TDE1')
plt.errorbar(M_BH_wvrs[24], M_GAL_grr[24], yerr = yerror7, xerr = xerror7, fmt='o', label='i16fnl')
plt.errorbar(M_BH_wvrs[28], M_GAL_grr[28], yerr = yerror8, xerr = xerror8, fmt='o', label='i16axa')
plt.errorbar(M_BH_wvrs[30], M_GAL_grr[30], yerr = yerror9, xerr = xerror9, fmt='o', label='D3-13')
plt.legend(loc = 'lower right', prop={"size":8})
plt.show()

# %% [markdown]
# #### Our Comparison with Wevers X Graur

# %%
yerror1 = [[GALerr_min[0]], [GALerr_max[0]]]
xerror1 = [[BHerr_min[0]], [BHerr_max[0]]]

yerror2 = [[GALerr_min[1]], [GALerr_max[1]]]
xerror2 = [[BHerr_min[1]], [BHerr_max[1]]]

yerror3 = [[GALerr_min[14]], [GALerr_max[14]]]
xerror3 = [[BHerr_min[14]], [BHerr_max[14]]]

yerror4 = [[GALerr_min[15]], [GALerr_max[15]]]
xerror4 = [[BHerr_min[15]], [BHerr_max[15]]]

yerror5 = [[GALerr_min[17]], [GALerr_max[17]]]
xerror5 = [[BHerr_min[17]], [BHerr_max[17]]]

yerror6 = [[GALerr_min[19]], [GALerr_max[19]]]
xerror6 = [[BHerr_min[19]], [BHerr_max[19]]]

yerror7 = [[GALerr_min[24]], [GALerr_max[24]]]
xerror7 = [[BHerr_min[24]], [BHerr_max[24]]]

yerror8 = [[GALerr_min[28]], [GALerr_max[28]]]
xerror8 = [[BHerr_min[28]], [BHerr_max[28]]]

yerror9 = [[GALerr_min[30]], [GALerr_max[30]]]
xerror9 = [[BHerr_min[30]], [BHerr_max[30]]]


plt.ylabel('Galaxy Mass')
plt.title('Comparison scatter - Wevers 2017 X Graur 2018')
plt.xlabel('Black Hole Mass')
plt.errorbar(M_BH[0], M_GAL[0], yerr = yerror1, xerr = xerror1, fmt='o', label='A14ae')
plt.errorbar(M_BH[1], M_GAL[1], yerr = yerror2, xerr = xerror2, fmt='o', label='A14li')
plt.errorbar(M_BH[14], M_GAL[14], yerr = yerror3, xerr = xerror3, fmt='o', label='i15af')
plt.errorbar(M_BH[15], M_GAL[15], yerr = yerror4, xerr = xerror4, fmt='o', label='PS10jh')
plt.errorbar(M_BH[17], M_GAL[17], yerr = yerror5, xerr = xerror5, fmt='o', label='PT09djl')
plt.errorbar(M_BH[19], M_GAL[19], yerr = yerror6, xerr = xerror6, fmt='o', label='TDE1')
plt.errorbar(M_BH[24], M_GAL[24], yerr = yerror7, xerr = xerror7, fmt='o', label='i16fnl')
plt.errorbar(M_BH[28], M_GAL[28], yerr = yerror8, xerr = xerror8, fmt='o', label='i16axa')
plt.errorbar(M_BH[30], M_GAL[30], yerr = yerror9, xerr = xerror9, fmt='o', label='D3-13')
plt.legend(loc = 'upper right', prop={"size":8})
plt.show()

# %% [markdown]
# #### Literature Scatter Comparison same plot - Wevers X Graur

# %%
yerror1 = [[M_GALerr_min_grr[0]], [M_GALerr_max_grr[0]]]
xerror1 = [[M_BHerr_min_wvrs[0]], [M_BHerr_max_wvrs[0]]]

yerror2 = [[M_GALerr_min_grr[1]], [M_GALerr_max_grr[1]]]
xerror2 = [[M_BHerr_min_wvrs[1]], [M_BHerr_max_wvrs[1]]]

yerror3 = [[M_GALerr_min_grr[14]], [M_GALerr_max_grr[14]]]
xerror3 = [[M_BHerr_min_wvrs[14]], [M_BHerr_max_wvrs[14]]]

yerror4 = [[M_GALerr_min_grr[15]], [M_GALerr_max_grr[15]]]
xerror4 = [[M_BHerr_min_wvrs[15]], [M_BHerr_max_wvrs[15]]]

yerror5 = [[M_GALerr_min_grr[17]], [M_GALerr_max_grr[17]]]
xerror5 = [[M_BHerr_min_wvrs[17]], [M_BHerr_max_wvrs[17]]]

yerror6 = [[M_GALerr_min_grr[19]], [M_GALerr_max_grr[19]]]
xerror6 = [[M_BHerr_min_wvrs[19]], [M_BHerr_max_wvrs[19]]]
          
yerror7 = [[M_GALerr_min_grr[24]], [M_GALerr_max_grr[24]]]
xerror7 = [[M_BHerr_min_wvrs[24]], [M_BHerr_max_wvrs[24]]]

yerror8 = [[M_GALerr_min_grr[28]], [M_GALerr_max_grr[28]]]
xerror8 = [[M_BHerr_min_wvrs[28]], [M_BHerr_max_wvrs[28]]]

yerror9 = [[M_GALerr_min_grr[30]], [M_GALerr_max_grr[30]]]
xerror9 = [[M_BHerr_min_wvrs[30]], [M_BHerr_max_wvrs[30]]]

yerror12 = [[GALerr_min[0]], [GALerr_max[0]]]
xerror12 = [[BHerr_min[0]], [BHerr_max[0]]]

yerror22 = [[GALerr_min[1]], [GALerr_max[1]]]
xerror22 = [[BHerr_min[1]], [BHerr_max[1]]]

yerror32 = [[GALerr_min[14]], [GALerr_max[14]]]
xerror32 = [[BHerr_min[14]], [BHerr_max[14]]]

yerror42 = [[GALerr_min[15]], [GALerr_max[15]]]
xerror42 = [[BHerr_min[15]], [BHerr_max[15]]]

yerror52 = [[GALerr_min[17]], [GALerr_max[17]]]
xerror52 = [[BHerr_min[17]], [BHerr_max[17]]]

yerror62 = [[GALerr_min[19]], [GALerr_max[19]]]
xerror62 = [[BHerr_min[19]], [BHerr_max[19]]]

yerror72 = [[GALerr_min[24]], [GALerr_max[24]]]
xerror72 = [[BHerr_min[24]], [BHerr_max[24]]]

yerror82 = [[GALerr_min[28]], [GALerr_max[28]]]
xerror82 = [[BHerr_min[28]], [BHerr_max[28]]]

yerror92 = [[GALerr_min[30]], [GALerr_max[30]]]
xerror92 = [[BHerr_min[30]], [BHerr_max[30]]]


plt.ylabel('Galaxy Mass')
plt.title('Combined Literature scatter - Wevers 2017 X Graur 2018')
plt.xlabel('Black Hole Mass')

plt.errorbar(M_BH_wvrs[0], M_GAL_grr[0], yerr = yerror1, xerr = xerror1, fmt='o', label='A14ae', color='tab:blue')
plt.errorbar(M_BH_wvrs[1], M_GAL_grr[1], yerr = yerror2, xerr = xerror2, fmt='o', label='A14li', color='tab:orange')
plt.errorbar(M_BH_wvrs[14], M_GAL_grr[14], yerr = yerror3, xerr = xerror3, fmt='o', label='i15af', color='tab:green')
plt.errorbar(M_BH_wvrs[15], M_GAL_grr[15], yerr = yerror4, xerr = xerror4, fmt='o', label='PS10jh', color='tab:red')
plt.errorbar(M_BH_wvrs[17], M_GAL_grr[17], yerr = yerror5, xerr = xerror5, fmt='o', label='PT09djl', color='tab:purple')
plt.errorbar(M_BH_wvrs[19], M_GAL_grr[19], yerr = yerror6, xerr = xerror6, fmt='o', label='TDE1', color='tab:brown')
plt.errorbar(M_BH_wvrs[24], M_GAL_grr[24], yerr = yerror7, xerr = xerror7, fmt='o', label='i16fnl', color='tab:pink')
plt.errorbar(M_BH_wvrs[28], M_GAL_grr[28], yerr = yerror8, xerr = xerror8, fmt='o', label='i16axa', color='tab:gray')
plt.errorbar(M_BH_wvrs[30], M_GAL_grr[30], yerr = yerror9, xerr = xerror9, fmt='o', label='D3-13', color='tab:olive')

plt.errorbar(M_BH[0], M_GAL[0], yerr = yerror12, xerr = xerror12, fmt='o', color='tab:blue')
plt.errorbar(M_BH[1], M_GAL[1], yerr = yerror22, xerr = xerror22, fmt='o', color='tab:orange')
plt.errorbar(M_BH[14], M_GAL[14], yerr = yerror32, xerr = xerror32, fmt='o', color='tab:green')
plt.errorbar(M_BH[15], M_GAL[15], yerr = yerror42, xerr = xerror42, fmt='o', color='tab:red')
plt.errorbar(M_BH[17], M_GAL[17], yerr = yerror52, xerr = xerror52, fmt='o', color='tab:purple')
plt.errorbar(M_BH[19], M_GAL[19], yerr = yerror62, xerr = xerror62, fmt='o', color='tab:brown')
plt.errorbar(M_BH[24], M_GAL[24], yerr = yerror72, xerr = xerror72, fmt='o', color='tab:pink')
plt.errorbar(M_BH[28], M_GAL[28], yerr = yerror82, xerr = xerror82, fmt='o', color='tab:gray')
plt.errorbar(M_BH[30], M_GAL[30], yerr = yerror92, xerr = xerror92, fmt='o', color='tab:olive')

plt.legend(loc = 'upper left', prop={"size":8})
plt.show()
